# %% [markdown]
# #                                           EDA_SHARK_TANK_INDIA

# %%
''' Q1. Find the number of episodes?
Q2. Max, min , mean of asked amount,asked equity, asked valuation? 
Q3. Max & Min asked- equity,asked-valuation and asked amount episode-wise? 
Q4. Brand names in which 2 ,3 or 4 sharks are invested? 
Q5. Episode wise minimum and maximum of sharks invested? 
Q6. Minimum and Maximum sharks invested in each episode?
Q7. Brand names who ask for 1 crore and got a deal? 
Q8. Brand names where deal equity is between 0 to 50? 
Q9. Find the number of brands participated in each episode? 
Q10. How many sharks participated in this show and What were their names? 
Q11. Find appearance of each sharks? 
Q12. How many entrepreneurs were present? 
Q13. How many times each shark invested the deal? 
Q14. Find the equity percent that each sharks gets? 
Q15. Find the total number of amount invested in this show? '''

# %%
import numpy as np
import pandas as pd
import statistics as stat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\Avinash'

# %%
shark_Tank_Dataset=pd.read_excel("C:\\Users\\Avinash\\Downloads\\04_EDA_Shark_Tank-20230531T031125Z-001/04_EDA_Shark_Tank\EDA_Shark_Tank_India.xlsx")
shark_Tank_Dataset
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %% [markdown]
# # Q1. Find the number of episodes?

# %%
data=shark_Tank_Dataset["episode_number"].unique()

len(data)
# Out:
# 35

# %% [markdown]
# # Q2. Max, min , mean of asked amount,asked equity, asked valuation?

# %%
shark_Tank_Dataset[["pitcher_ask_amount","ask_equity","ask_valuation"]].describe()
# Out:
#        pitcher_ask_amount  ask_equity  ask_valuation
# count          117.000000  117.000000     117.000000
# mean           319.854709    5.188034    3852.462479
# std           2767.842777    3.892121   11931.601957
# min              0.001010    0.250000       0.010000
# 25%             45.000000    2.500000     666.670000
# 50%             50.000000    5.000000    1250.000000
# 75%             80.000000    7.500000    2857.140000
# max          30000.000000   25.000000  120000.000000

# %% [markdown]
# # Q3. Max & Min asked- equity,asked-valuation and asked amount episode-wise?

# %%
shark_Tank_Dataset[["pitcher_ask_amount","ask_equity","ask_valuation"]].groupby(shark_Tank_Dataset["episode_number"]).min()
# Out:
#                 pitcher_ask_amount  ask_equity  ask_valuation
# episode_number
# 1                         25.00000        5.00         250.00
# 2                         50.00000        1.00        1000.00
# 3                         50.00000        0.25        1875.00
# 4                         50.00000        4.00         500.00
# 5                         10.00000        1.00          50.00
# 6                         45.00000        1.00         500.00
# 7                         50.00000        1.00         666.67
# 8                         30.00000        2.50         746.67
# 9                         50.00000        2.50        1000.00
# 10                        25.00000        2.00         500.00
# 11                        30.00000        5.00         300.00
# 12                        40.00000        3.00         800.00
# 13                        30.00000        2.00         500.00
# 14                        45.00000        3.00         900.00
# ...

# %%
shark_Tank_Dataset[["pitcher_ask_amount","ask_equity","ask_valuation"]].groupby(shark_Tank_Dataset["episode_number"]).max()
# Out:
#                 pitcher_ask_amount  ask_equity  ask_valuation
# episode_number
# 1                             50.0        15.0        1000.00
# 2                             70.0         5.0        7000.00
# 3                            100.0         4.0       40000.00
# 4                             75.0        10.0        1875.00
# 5                            100.0        20.0       10000.00
# 6                            100.0        10.0       10000.00
# 7                            100.0         7.5        7500.00
# 8                             56.0         7.5        2000.00
# 9                            100.0         5.0        2000.00
# 10                            30.0         5.0        1500.00
# 11                         30000.0        25.0      120000.00
# 12                            75.0         5.0        1875.00
# 13                            50.0        10.0        2500.00
# 14                           100.0         5.0        3333.33
# ...

# %%
shark_Tank_Dataset[["pitcher_ask_amount","ask_equity","ask_valuation"]].groupby(shark_Tank_Dataset["episode_number"]).describe()
# Out:
#                pitcher_ask_amount                                        \
#                             count          mean           std       min
# episode_number
# 1                             3.0     38.333333     12.583057  25.00000
# 2                             3.0     56.666667     11.547005  50.00000
# 3                             3.0     75.000000     25.000000  50.00000
# 4                             3.0     58.333333     14.433757  50.00000
# 5                             3.0     53.333333     45.092498  10.00000
# 6                             3.0     65.000000     30.413813  45.00000
# 7                             3.0     75.000000     25.000000  50.00000
# 8                             3.0     45.333333     13.613719  30.00000
# 9                             3.0     66.666667     28.867513  50.00000
# 10                            3.0     28.333333      2.886751  25.00000
# 11                            3.0  10026.666667  17297.416956  30.00000
# ...

# %% [markdown]
# # Q4. Brand names in which 2 ,3 or 4 sharks are invested?

# %%
shark_Tank_Dataset[["brand_name","total_sharks_invested"]][(shark_Tank_Dataset["total_sharks_invested"]>=2) & (shark_Tank_Dataset["total_sharks_invested"]<=4 )]
# Out:
#                          brand_name  total_sharks_invested
# 0               BluePine Industries                      3
# 1                     Booz scooters                      2
# 2               Heart up my Sleeves                      2
# 9                             Cosiq                      2
# 11                           Bummer                      2
# 12                      Revamp Moto                      2
# 18               Raising Superstars                      2
# 21                     Beyond Snack                      2
# 22   Vivalyf Innovations- Easy Life                      2
# 24                            Altor                      2
# 25                            Ariro                      2
# 27                          Nuutjob                      3
# 28                         Meatyour                      3
# 29                        EventBeep                      3
# 32                            Farda                      2
# ...

# %% [markdown]
# # Q5. Episode wise minimum and maximum of sharks invested?

# %%
shark_Tank_Dataset[["brand_name","deal_amount"]].groupby(shark_Tank_Dataset["episode_number"]).max()
# Out:
#                                     brand_name  deal_amount
# episode_number
# 1                          Heart up my Sleeves         75.0
# 2                                   Tagz Foods         70.0
# 3                                  Qzense Labs         75.0
# 4                                 JhaJi Achaar         75.0
# 5                           Shrawani Engineers        100.0
# 6                                  Skippi Pops        100.0
# 7                                     Torch-it        100.0
# 8               Vivalyf Innovations- Easy Life         56.0
# 9                              Kabira Handmade         50.0
# 10                                     Nuutjob         30.0
# 11                                  Gopal's 56         50.0
# 12                                    SweeDesi         75.0
# 13                             The Yarn Bazaar        105.0
# 14                           The Renal Project        100.0
# ...

# %%
shark_Tank_Dataset[["brand_name","deal_amount"]].groupby(shark_Tank_Dataset["episode_number"]).min()
# Out:
#                               brand_name  deal_amount
# episode_number
# 1                    BluePine Industries     25.00000
# 2                           Agro tourism      0.00000
# 3                                   NOCD      0.00000
# 4                                 Bummer      0.00000
# 5                           Hungry Heads      0.00000
# 6                                Hecolll      0.00000
# 7                          La Kheer Deli      0.00000
# 8                           Beyond Snack     30.00000
# 9                                  Altor      0.00000
# 10                             EventBeep     25.00000
# 11              ARRCOAT Surface Textures      0.00000
# 12                        Auli Lifestyle      0.00000
# 13                                 Annie     50.00000
# 14                  Good Good Piggy Bank      0.00000
# 15                               Cocofit      0.00005
# 16                          Bamboo India      0.00000
# ...

# %% [markdown]
# # Q6. Minimum and Maximum sharks invested in each episode?total_sharks_invested

# %%
shark_Tank_Dataset[["brand_name","total_sharks_invested"]].groupby(shark_Tank_Dataset["episode_number"]).max()
# Out:
#                                     brand_name  total_sharks_invested
# episode_number
# 1                          Heart up my Sleeves                      3
# 2                                   Tagz Foods                      1
# 3                                  Qzense Labs                      1
# 4                                 JhaJi Achaar                      2
# 5                           Shrawani Engineers                      2
# 6                                  Skippi Pops                      5
# 7                                     Torch-it                      2
# 8               Vivalyf Innovations- Easy Life                      2
# 9                              Kabira Handmade                      2
# 10                                     Nuutjob                      3
# 11                                  Gopal's 56                      2
# 12                                    SweeDesi                      3
# ...

# %%
shark_Tank_Dataset[["brand_name","total_sharks_invested"]].groupby(shark_Tank_Dataset["episode_number"]).min()
# Out:
#                               brand_name  total_sharks_invested
# episode_number
# 1                    BluePine Industries                      2
# 2                           Agro tourism                      0
# 3                                   NOCD                      0
# 4                                 Bummer                      0
# 5                           Hungry Heads                      0
# 6                                Hecolll                      0
# 7                          La Kheer Deli                      0
# 8                           Beyond Snack                      1
# 9                                  Altor                      0
# 10                             EventBeep                      3
# 11              ARRCOAT Surface Textures                      0
# 12                        Auli Lifestyle                      0
# 13                                 Annie                      2
# ...

# %% [markdown]
# # Q7. Brand names who ask for 1 crore and got a deal?

# %%
shark_Tank_Dataset[["brand_name","pitcher_ask_amount","deal_amount"]][(shark_Tank_Dataset["deal_amount"]==100) &  (shark_Tank_Dataset["pitcher_ask_amount"]==100)]
# Out:
#              brand_name  pitcher_ask_amount  deal_amount
# 12          Revamp Moto               100.0        100.0
# 18   Raising Superstars               100.0        100.0
# 39    The Renal Project               100.0        100.0
# 64           Get a Whey               100.0        100.0
# 79  Sunfox Technologies               100.0        100.0
# 87   Insurance Samadhan               100.0        100.0

# %% [markdown]
# # Q8. Brand names where deal equity is between 0 to 50?

# %%
shark_Tank_Dataset[["brand_name","deal_equity"]][(shark_Tank_Dataset["deal_equity"]>0) & (shark_Tank_Dataset["deal_equity"]<50)]
# Out:
#               brand_name  deal_equity
# 0    BluePine Industries        16.00
# 2    Heart up my Sleeves        30.00
# 3             Tagz Foods         2.75
# 7              Peeschute         6.00
# 8                   NOCD        15.00
# ..                   ...          ...
# 106        Colour Me Mad        25.00
# 108           Tweek Labs        10.00
# 109               Proxgy        10.00
# 110   Nomad Food Project        20.00
# 114        Jain Shikanji        30.00
#
# [62 rows x 2 columns]

# %% [markdown]
# # Q9. Find the number of brands participated in each episode?

# %%
df=shark_Tank_Dataset[["brand_name"]].groupby(shark_Tank_Dataset["episode_number"]).count()
dff=df.rename(columns={"brand_name":"no_of_Brand"})
dff
# Out:
#                 no_of_Brand
# episode_number
# 1                         3
# 2                         3
# 3                         3
# 4                         3
# 5                         3
# 6                         3
# 7                         3
# 8                         3
# 9                         3
# 10                        3
# 11                        3
# 12                        3
# 13                        3
# 14                        3
# 15                        3
# 16                        4
# 17                        4
# 18                        4
# 19                        4
# 20                        3
# 21                        3
# 22                        4
# 23                        4
# 24                        3
# 25                        3
# 26                        3
# 27                        4
# 28                        3
# 29                        3
# 30                        4
# 31                        4
# ...

# %% [markdown]
# # Q10. How many sharks participated in this show and What were their names?

# %%
shark_Tank_Dataset.columns
# Out:
# Index(['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
#        'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
#        'deal_equity', 'deal_valuation', 'ashneer_present', 'anupam_present',
#        'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
#        'ghazal_present', 'ashneer_deal', 'anupam_deal', 'aman_deal',
#        'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
#        'total_sharks_invested', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
shark_Tank_Dataset.iloc[0,11:18].count()
# Out:
# 7

# %%
df=shark_Tank_Dataset.columns[11:18]
j=0
for i in df:
    print(i)
    j=j+1
print("total no. of sharks " , j)
# Out:
# ashneer_present
# anupam_present
# aman_present
# namita_present
# vineeta_present
# peyush_present
# ghazal_present
# total no. of sharks 7

# %% [markdown]
# # Q11. Find appearance of each sharks?

# %%
df=shark_Tank_Dataset[["ashneer_present","anupam_present","aman_present","namita_present","vineeta_present","peyush_present","ghazal_present"]].sum()
dff=pd.DataFrame(df,columns=["sharks_appearence"])
dff
# Out:
#                  sharks_appearence
# ashneer_present                 98
# anupam_present                 117
# aman_present                    98
# namita_present                 106
# vineeta_present                 66
# peyush_present                  88
# ghazal_present                  26

# %% [markdown]
# # Q12. How many entrepreneurs were present?

# %%
shark_Tank_Dataset[["brand_name"]].count()
# Out:
# brand_name    117
# dtype: int64

# %% [markdown]
# # Q13. How many times each shark invested the deal?

# %%
shark_Tank_Dataset[["ashneer_deal","anupam_deal","aman_deal","namita_deal","vineeta_deal","peyush_deal","ghazal_deal"]].sum()
# Out:
# ashneer_deal    21
# anupam_deal     24
# aman_deal       28
# namita_deal     22
# vineeta_deal    15
# peyush_deal     27
# ghazal_deal      7
# dtype: int64

# %% [markdown]
# # Q14. Find the equity percent that each sharks gets?

# %%
print("ashneer_deal " , shark_Tank_Dataset[["equity_per_shark"]][shark_Tank_Dataset["ashneer_deal"]==1].sum())
print("anupam_deal  ",shark_Tank_Dataset[["equity_per_shark"]][shark_Tank_Dataset["anupam_deal"]==1].sum())
print("aman_deal  ",shark_Tank_Dataset[["equity_per_shark"]][shark_Tank_Dataset["aman_deal"]==1].sum())
print("namita_deal  ",shark_Tank_Dataset[["equity_per_shark"]][shark_Tank_Dataset["namita_deal"]==1].sum())
print("vineeta_deal  ",shark_Tank_Dataset[["equity_per_shark"]][shark_Tank_Dataset["vineeta_deal"]==1].sum())
# Out:
# ashneer_deal  equity_per_shark    93.25
# dtype: float64
# anupam_deal   equity_per_shark    166.35
# dtype: float64
# aman_deal   equity_per_shark    160.263333
# dtype: float64
# namita_deal   equity_per_shark    134.783333
# dtype: float64
# vineeta_deal   equity_per_shark    131.533333
# dtype: float64

# %% [markdown]
# # Q15. Find the total number of amount invested in this show?

# %%
[shark_Tank_Dataset["deal_amount"].sum()]
# Out:
# [3742.00106]
